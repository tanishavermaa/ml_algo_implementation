# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib_inline

# %%
df=pd.read_csv("regression_raw_data.csv")

# %%
df.head(3)
# Out:
#                   DATE  VISIBILITY  DRYBULBTEMPF  WETBULBTEMPF  DewPointTempF  \
# 0  2010-01-01 00:51:00         6.0            33            32             31
# 1  2010-01-01 01:51:00         6.0            33            33             32
# 2  2010-01-01 02:51:00         5.0            33            33             32
#
#    RelativeHumidity  WindSpeed  WindDirection  StationPressure  \
# 0                92          0              0            29.97
# 1                96          0              0            29.97
# 2                96          0              0            29.97
#
#    SeaLevelPressure  Precip
# 0             29.99    0.01
# 1             29.99    0.02
# 2             29.99    0.02

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# DATE                0
# VISIBILITY          0
# DRYBULBTEMPF        0
# WETBULBTEMPF        0
# DewPointTempF       0
# RelativeHumidity    0
# WindSpeed           0
# WindDirection       0
# StationPressure     0
# SeaLevelPressure    0
# Precip              0
# dtype: int64

# %%
df.dtypes
# Out:
# DATE                 object
# VISIBILITY          float64
# DRYBULBTEMPF          int64
# WETBULBTEMPF          int64
# DewPointTempF         int64
# RelativeHumidity      int64
# WindSpeed             int64
# WindDirection         int64
# StationPressure     float64
# SeaLevelPressure    float64
# Precip              float64
# dtype: object

# %%
df['DATE']= pd.to_datetime(df['DATE'])
df['MONTH']=df['DATE'].dt.month

# %%
df=df.drop(['DATE'],axis=1)

# %%
df.head()
# Out:
#    VISIBILITY  DRYBULBTEMPF  WETBULBTEMPF  DewPointTempF  RelativeHumidity  \
# 0         6.0            33            32             31                92
# 1         6.0            33            33             32                96
# 2         5.0            33            33             32                96
# 3         5.0            33            33             32                96
# 4         5.0            33            32             31                92
#
#    WindSpeed  WindDirection  StationPressure  SeaLevelPressure  Precip  MONTH
# 0          0              0            29.97             29.99    0.01      1
# 1          0              0            29.97             29.99    0.02      1
# 2          0              0            29.97             29.99    0.02      1
# 3          0              0            29.95             29.97    0.02      1
# 4          0              0            29.93             29.96    0.02      1

# %%
df.to_csv("regression_cleaned_data.csv")

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.clustermap(df.corr())

# %%
df.describe()
# Out:
#          VISIBILITY  DRYBULBTEMPF  WETBULBTEMPF  DewPointTempF  \
# count  75083.000000  75083.000000  75083.000000   75083.000000
# mean       9.211896     55.355527     49.327544      42.424024
# std        2.202311     17.394334     16.182867      19.577957
# min        0.000000      1.000000     -1.000000     -19.000000
# 25%       10.000000     42.000000     36.000000      27.000000
# 50%       10.000000     56.000000     50.000000      44.000000
# 75%       10.000000     70.000000     64.000000      59.000000
# max       14.000000    102.000000     85.000000      84.000000
#
#        RelativeHumidity     WindSpeed  WindDirection  StationPressure  \
# count      75083.000000  75083.000000   75083.000000     75083.000000
# mean          64.812075     11.253240     196.550751        30.005579
# std           19.898962      6.101048     107.692804         0.235172
# min            8.000000      0.000000       0.000000        28.520000
# 25%           49.000000      7.000000     110.000000        29.860000
# 50%           66.000000     10.000000     200.000000        30.000000
# 75%           82.000000     15.000000     290.000000        30.150000
# max          100.000000     53.000000     360.000000        30.830000
#
#        SeaLevelPressure        Precip         MONTH
# count      75083.000000  75083.000000  75083.000000
# mean          30.026049      0.005478      6.352663
# std            0.234069      0.036161      3.430669
# min           28.540000      0.000000      1.000000
# 25%           29.880000      0.000000      3.000000
# 50%           30.020000      0.000000      6.000000
# 75%           30.170000      0.000000      9.000000
# max           30.850000      2.410000     12.000000

# %%
df['VISIBILITY'].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of VISIBILITY
# 10.00    63371
# 9.00      1748
# 8.00      1582
# 7.00      1375
# 6.00      1210
# 5.00       934
# 3.00       694
# 2.00       595
# 4.00       536
# 0.25       521
# 0.50       512
# 1.00       435
# 2.50       381
# 1.50       340
# 0.12       336
# 0.00       245
# 0.75       202
# 1.75        34
# 1.25        31
# 14.00        1
# Name: count, dtype: int64>

# %%
df.shape
# Out:
# (75083, 11)
